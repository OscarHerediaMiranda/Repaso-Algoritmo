# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarHerediaMiranda/Repaso-Algoritmo/blob/main/Preguntas_Repaso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile R1.cpp
# #include <iostream>
# //Pregunta 1
# /*En una clase, se pueden crear metodos, cronstructores.
# Se puede acceder de manera privada o publica.
# Mientras que en struct solamente se puede acceder de manera publica.*/
#
# //Pregunta 2
# /*La herencia es cuando una clase obtiene todos los metodos de su clase padre.
# Una clase de tipo publico es cuando se puede acceder libremente a una clase estando en otra clase.
# En cambio una clase de tipo privado es cuando no se puede acceder libremente a sus metodos y atributos
# en otra clase.Es decir, solamente se puede acceder estando en misma clase.*/
#
# //Pregunta 3
# /*Si la clase base es la clase padre de la clase derivada no es necesario sobreescribirlo por la herencia,
# ya que la herencia hace que la clase derivada ya contenga ese metodo.*/
#
# //Pregunta 4
# /*Definimos una clase y hacemos uso de virtual a sus metodos y no les definimos las acciones que debe realizar.
# Eso se define en sus clases hijas.*/
#
# //Pregunta 5
# /*Mostraria error ya que no se puede instanciar objetos en una clase abstracta.*/
#
# //Pregunta 6
# /*Un destructor sirve para eliminar un objeto de una clase. Sirve principalmente para eliminar espacio de memoria.
# Se crea similar a un constructor pero con ~ delante. En ella contiene el elemento que queremos eliminar.*/
#
# //Pregunta 7
# /*Se asigna memoria utilizando punteros.*/
#
# //Pregunta 8
# /*Si se ha utilizado para darle otro uso a los operadores ya conocinos como el >>, +, */
#
# //Pregunta 9
# /*El encapsulamiento hace referencia a la proteccion de los datos utilizando private, protected.
# La abstraccion hace referencia a la interpretacion y diseño que implica reconocer y enfocarse en las
# caracteristicas importantes de una situacion y objeto.*/
#
# //Pregunta 10
# /*Es ejecutada la clase base.*/
#
# //Pregunta 11
# /*Despues de poner el nombre del constructor de la clase derivada se hace uso de los : con el nombre
# del constructor de la clase base con sus respectivos parametros para que ya no repita los pasos realizados
# por el constructor de la clase base.*/
#
# //Pregunta 12
# /*Una herencia es cuando una clase derivada obtiene los metodos y atributos de la clase base.*/
#
# //Pregunta 13
# /*El namespace std tiene la funcionalidad de hacer uso del cin y cout.*/
#
# //Pregunta 14
# /*Se crea una clase abstracta para utilizar los mismos metodos en varias clases.*/
#
# //Pregunta 15
# /*La pila es una estructura de datos que sirve para almacenar datos y se usa la nomeclatura LIFO,
# es decir, el ultimo que ingresa es el primero que sale.*/
#
# //Pregunta 16
# /*El polimorfismo es cuando las clases derivadas utilizan el mismo nombre del metodo,
# pero hacen diferentes acciones.*/
#
# //Pregunta 17
# /*Es cuando el compilador añade codigo cuando identifica el tipo de objeto en tiempo de ejecucion y
# luego hace coincidir la llamada con la definicion de la funcion correcta. Esto se hace declarando una
# funcion virtual.*/
#
# //Pregunta 18
# /*Lista, Pila, Cola, clases*/
#
# //Pregunta 19
# /*Se cerrara automaticamente el archivo una vez que se salga del programa, aunque
# es necesario cerrarlo antes ya que se corre el riesgo de dañar o perder la informacion*/
#
# //Pregunta 20
# /*Es la asignacion de un objeto de la clase derivada a la clase base, perdiendo asi informacion*/
#
# //Pregunta 21
# /*Vector, map, set, pair porque necesitabamos almacenar valores de una manera distinta a lo que ya
# conociamos de una manera mas eficiente.*/
#
# //Pregunta 22
# /*Se escribe el constructor para poder inicializar los atributos de cada clase.*/
#
# //Pregunta 23
# /*Se pueden instanciar objetos por la clase y se pueden inicializar los atributos por defecto
# porque c++ crea los constructores de manera implicita.*/
#
# //Pregunta 24
# /*No pueden ser sobrecargados ya que no tienen valor de retorno ni parametro.*/
#
# //Pregunta 25
# /*Una Tupla almacena un valor en una posicion de un vector. Un vector es un conjunto de Tuplas.*/
#
# //Pregunta 26
# /*Por lo general, primero se crea el constructor que no tiene parametros, luego el constructor que
# contiene parametros, pero como es de una clase derivada, realiza primero el constructor de la clase
# base y luego el contenido del contructor de la clase derivada.*/
#
# //Pregunta 27
# /*La principal diferencia entre la agregacion y composicion es que la agregacion implica una relacion
# en la que el hijo puede existir independientemente del padre. En cambio, en la composicion se insinua
# una relacion donde el niño no puede existir independientemente del padre.*/
#
# //Pregunta 28
# /*Con un try y un catch en donde si es que hay un error, el catch captura dicho error, ese error debe
# ocurrir dentro del try.*/
#
# //Pregunta 29
# /*Tenemos dos clases. Una clase empresa y una clase persona y la relacion es de 1 a n. La clase
# empresa depende de la clase persona y tambien la clase persona depende de la clase empresa.*/
#
# //Pregunta 30
# /*No, un padre puede tener varios hijos pero no viceversa.*/
#
# //Pregunta 31
# /*Por ejemplo la relacion entre una clase persona y una clase tarjeta de credito porque una tarjeta
# esta asociada a una persona y una persona tiene 0 o 1 tarjeta de credito.*/
# int main()
# {
#
# }
